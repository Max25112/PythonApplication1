# %%
### importing the library
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##number of point of the time series
nsample = 1024
## simulate a simple sinusoidal function
x1 = np.linspace(0, 100, nsample)
y=np.sin(x1)

# %%
fig, ax = plt.subplots()
ax.plot(x1, y, label="Data")

# %%
sigma = 0.3
y =sigma * np.random.normal(size=nsample)

# %%
fig, ax = plt.subplots()
ax.plot(x1, y, label="Data")

# %%
sigma = 0.3
y =np.sin(x1)+sigma * np.random.normal(size=nsample)
fig, ax = plt.subplots()
ax.plot(x1, y, label="Data")

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima_process import arma_generate_sample
np.random.seed(12345)

arparams = np.array([.75, -.25])
maparams = np.array([.65, .35])
arparams = np.r_[1, -arparams]
maparam = np.r_[1, maparams]

y = arma_generate_sample(arparams, maparams, nsample)
fig, ax = plt.subplots()
ax.plot(x1, y, label="Data")

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jul  6 22:38:54 2018
@author: Lenovo
"""

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

'''importing the dataset'''

import statsmodels.api as sm

dataset_train = sm.datasets.sunspots.load_pandas().data
#setting up the series and date as index
training_set = dataset_train.iloc[:, 1:2]
training_set.index = pd.DatetimeIndex(start='1700', end='2009', freq='A')
#visualising the plot
training_set.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-85db5244de81> in <module>
#      16 #setting up the series and date as index
#      17 training_set = dataset_train.iloc[:, 1:2]
# ---> 18 training_set.index = pd.DatetimeIndex(start='1700', end='2009', freq='A')
#      19 #visualising the plot
#      20 training_set.plot()
#
# TypeError: __new__() got an unexpected keyword argument 'start'
